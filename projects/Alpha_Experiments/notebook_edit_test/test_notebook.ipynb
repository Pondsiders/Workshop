# %% [markdown]
# # Cell 0: The Beginning
#
# This is the first cell. It should stay at position 0.

# %%
# Cell 1: First code cell
print("I am cell 1")

# %%
# FIRST SEQUENTIAL INSERT (after cell-1)
print("I should appear right after cell-1")

# %%
# SECOND SEQUENTIAL INSERT (after the first insert)
print("I should appear right after the FIRST SEQUENTIAL INSERT")

# %%
# Cell 2: MODIFIED BY REPLACE TEST
print("I am cell 2 - I have been modified!")
x = 42  # Added this line

# %%
# NEW CELL: Inserted after cell-2
print("I am the NEW cell, inserted after cell-2")
print("I should be at position 3")

# %%
# Cell 3: Third code cell
print("I am cell 3")

# %% [markdown]
# # Cell 4: The End
#
# This is the last cell. It should stay at the end (until we mess with things).

# %% [markdown]
# # APPENDED AT END
#
# This cell was inserted after cell-4, so it should be the new last cell.
